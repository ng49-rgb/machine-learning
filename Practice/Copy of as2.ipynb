# %%
#q1
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."
words = sentence.count(" ")+1 #counted no. of spaces and then _+1
print(words)
# Out:
# 20

# %%
#q2
num = int(input("Write your no."))
print("No. is" , num)
s = "-"
result = s * num
print(result)
# Out:
# Write your no.3
# No. is 3
# ---

# %%
#q3
s = input("enter your string :")
print("your input is :", s)
print("Safe Bridge:" ,s.count(" ")==0)
#print(s.find(" ")== -1) # -1 is returned for find when no space is found.
# Out:
# enter your string :wev
# your input is : wev
# Safe Bridge: True

# %%
#q4
s = input("write 'd' letter containing string :")
print("You wrote:", s)
s2 = s.lower()
print("No. of D's :", s2.count('d'))
# Out:
# write 'd' letter containing string :DEcDdd
# You wrote: DEcDdd
# No. of D's : 4

# %%
#q5
'''s = input("Enter the word : ")
print("The word is : ", s)
length = (len(s))
half_length = length // 2 # becoz slicing need an int value and "/" gives float
if s [0:half_length] == s [-1:-half_length-1:-1] :
  print("Palindrome")
else :
   print("Not Palindrome")'''

str = "madam"
print(str==str[-1::-1])
# Out:
# True
