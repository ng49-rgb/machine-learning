# %%
#q1
wins = 5
draw = 2
loss = 3
print("Matches played : 10")
total_points = (wins * 3) + (draw * 2) + (loss * 0 )
#print("Total pts. after 10 matches :",total_points)
print(f"total pts: {total_points}")
# Out:
# Matches played : 10
# total pts: 19

# %%
#q2
'''x = 3
f1 = (x**2)+(x*3)-4
print(f1)

x = -1
f1 = (x**2)+(x*3)-4
print(f1)

x = 1
f1 = (x**2)+(x*3)-4
print(f1)'''

#approach 2
def f(x) :
  return x**2 + 3*x - 4

x1 = 3
x2 = -1
x3 = 1

print(f(x1))
print(f(x1)==0)
print(f(x2))
print(f(x2)==0)
print(f(x3))
print(f(x3)==0)
# Out:
# 14
# False
# -6
# False
# 0
# True

# %%
#q3
apple = 45
orange = 65
banana = 30
total = apple + orange + banana

print("apple_percent :" , (apple*100)/(total))
print("orange_percent :" , (orange*100)/(total))
print("banana_percent :" , (banana*100)/(total))
# Out:
# apple_percent : 32.142857142857146
# orange_percent : 46.42857142857143
# banana_percent : 21.428571428571427

# %%
#q4
total_m_majors = 30
total_E_majors = 45
total_P_majors = 25
guessed_m = 20
guessed_E = 30
guessed_P = 20
print("1st round accuracy :" ,(guessed_m * 100)/(total_m_majors))
print("2nd round accuracy :" ,(guessed_E * 100)/(total_E_majors))
print("3rd round accuracy :" ,(guessed_P * 100)/(total_P_majors))
# Out:
# 1st round accuracy : 66.66666666666667
# 2nd round accuracy : 66.66666666666667
# 3rd round accuracy : 80.0
