# %%
type(0)
# Out:
# int

# %%
_var_2 = 10
print(_var_2)
#divison op gives float in python
# Out:
# 10

# %%
a = 1
b = 3
print(a==b)
print(a>=b)
print(a!=b)
print(a>b)
print(a<b)
# Out:
# False
# False
# True
# False
# True

# %%
print(12//9)
#
print('floor op')
# Out:
# 1
# floor op
